# %% [markdown]
# <div style="background:#03045E;padding:28px 32px;border-radius:16px;font-family:Arial,sans-serif;">
# <img src="../assets/jekacode-logo.png" alt="Jekacode" width="240"/>
# <p style="color:#16D365;font-size:12px;letter-spacing:2.5px;margin:18px 0 6px 0;">JEKACODE AI ENGINEERING · SETUP</p>
# <h1 style="color:#ffffff;margin:0;font-size:28px;">Is your computer ready?</h1>
# <p style="color:#d7deea;margin:10px 0 0 0;font-size:16px;">Run every cell. Green text is good. Red text is a clue.</p>
# </div>

# %%
import sys
from pathlib import Path

root = Path.cwd()
if not (root / "jekacode").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.append(str(root))

# %% [markdown]
# If a cell fails, read [setup/README.md](README.md) again. Ask Gemini: *Explain this error like I am 12.*

# %%
import sys
print('Python version:', sys.version.split()[0])
print('You want 3.11 or newer.')

# %%
from pathlib import Path
print('Course folder:', Path.cwd())

# %%
from jekacode.brand import NAVY, GREEN
print('Navy', NAVY)
print('Green', GREEN)
print('Brand colours loaded.')

# %%
from jekacode.ai import ask

print('Trying Gemini...')
print(ask('Reply with exactly this sentence: Jekacode is ready.', provider='gemini'))

# %% [markdown]
# <div style="border-left:6px solid #16D365;background:#F4F6FB;padding:14px 16px;border-radius:0 8px 8px 0;font-family:Arial,sans-serif;">
# <strong style="color:#03045E;">DeepSeek is optional today</strong>
# <p style="margin:8px 0 0 0;color:#1b1f2a;">If you do not have a DeepSeek key yet, skip the next cell. Gemini is enough for class.</p>
# </div>

# %%
from jekacode.ai import ask

print('Trying DeepSeek...')
print(ask('Reply with exactly this sentence: DeepSeek is ready.', provider='deepseek'))

# %% [markdown]
# ### You are ready when Gemini answered.
# Open [../week01-intro-to-ai/README.md](../week01-intro-to-ai/README.md).
