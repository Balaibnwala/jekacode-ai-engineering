# %% [markdown]
# <div style="background:#03045E;padding:28px 32px;border-radius:16px;font-family:Arial,sans-serif;">
# <img src="../assets/jekacode-logo.png" alt="Jekacode" width="240"/>
# <p style="color:#16D365;font-size:12px;letter-spacing:2.5px;margin:18px 0 6px 0;">JEKACODE AI ENGINEERING · TEST</p>
# <h1 style="color:#ffffff;margin:0;font-size:28px;">Test Gemini, Grok, DeepSeek, Ollama</h1>
# <p style="color:#d7deea;margin:10px 0 0 0;font-size:16px;">Latency, inconsistency, hallucination.</p>
# </div>

# %%
import sys
from pathlib import Path

root = Path.cwd()
if not (root / "jekacode").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.append(str(root))

# %% [markdown]
# Read [../guides/TEST_ALL_MODELS.md](../guides/TEST_ALL_MODELS.md) and [../guides/AI_ENGINEERING_TERMS.md](../guides/AI_ENGINEERING_TERMS.md) first. Skip any provider whose key you do not have.

# %%
from jekacode.ai import ask, ask_timed

PROMPT = "Reply with exactly: Jekacode is ready."
for name in ["gemini", "grok", "deepseek", "ollama"]:
    print("====", name, "====")
    result = ask_timed(PROMPT, provider=name)
    print("ok:", result["ok"], "latency_ms:", result["latency_ms"])
    print((result["text"] or result["error"] or "")[:400])
    print()

# %% [markdown]
# ### Inconsistency — same prompt three times (Gemini)

# %%
prompt = "Name one West African food in one word only."
for i in range(3):
    print(i + 1, ask(prompt, provider="gemini"))

# %% [markdown]
# ### Hallucination probe — a fee that is not in our handbook

# %%
print(ask(
    "What is the official transcript fee in naira at Greenfield Secondary School? Answer with a number only.",
    provider="gemini",
))
print("--- If it invented a number, that is a hallucination. The sample handbook does not list a fee. ---")
